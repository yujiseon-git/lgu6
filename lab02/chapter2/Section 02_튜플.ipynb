# %% [markdown]
# # Section 02. 튜플

# %% [markdown]
# ##1. 튜플 생성 자료 저장

# %%
prices_tuple=(85000, 140000, 200000)
print(prices_tuple)
prices_tuple1=85000, 140000, 200000
print(prices_tuple)
# Out:
# (85000, 140000, 200000)
# (85000, 140000, 200000)

# %% [markdown]
# ##2. 튜플 원소의 접근과 사용

# %%
prices_tuple=(85000, 140000, 200000)
prices_tuple[0]
# Out:
# 85000

# %% [markdown]
# 다음과 같이 튜플의 0번째 인덱스를 2000으로 변경하려고 하면 TypeError가 발생하는 것을 확인할 수 있다.

# %%
prices_tuple=(85000, 140000, 200000)
prices_tuple[0]=2000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-86cc04de02c9> in <cell line: 2>()
#       1 prices_tuple=(85000, 140000, 200000)
# ----> 2 prices_tuple[0]=2000
#
# TypeError: 'tuple' object does not support item assignment

# %%
prices_tuple=('삼성전자', 'LG전자', 'SK', 85000, 140000, 200000)
prices_tuple[2:4]
# Out:
# ('SK', 85000)
