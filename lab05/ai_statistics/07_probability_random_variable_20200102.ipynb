# %% [markdown]
# # 파이썬 기반의 AI를 위한 기초수학, 확률및통계

# %%
## 강봉주 
## bonjour.kang@gmail.com
##
## 확률과 확률 변수
##

# %%
# 필요한 패키지
import numpy as np
import scipy
from scipy import linalg as la
import matplotlib.pyplot as plt

import scipy.stats as ss
import sympy

# 한글출력
plt.rcParams['font.family'] = 'Malgun Gothic' #'AppleGothic' #  Windows 'Malgun Gothic' 
plt.rcParams['axes.unicode_minus'] = False

scipy.__version__
# Out:
# '1.15.3'

# %% [markdown]
# ## 확률 밀도 함수

# %%
# 예제: 이산형 확률 밀도 함수
# 이항 분포
# 4번 시행에서 성공확률이 1/2인 경우
# 𝐴={0, 1, 2}의 확률을 계산해보자

# %%
import numpy as np

dice = np.arange(1,7)

# 표본 공간 = 모든 경우의 수
# 두 개의 주사위 던질 때, 모든 조합(=통계)

sample_space = np.array([(i,j) for i in dice for j in dice])
c

# 두 주사위의 합이 7개인 경우의 확률을 구하세요

sum7 = np.array([result for result in sample_space if sum(result) == 7])
sum7
# Out:
# 표본공간 (총36)개
# array([[1, 6],
#        [2, 5],
#        [3, 4],
#        [4, 3],
#        [5, 2],
#        [6, 1]])

# %%
# 로또
# 전체 가능한 조합, 총 몇개가 나올것인가? 갯수
# 표본공간 크기
# 1, 2, 3, 4, 5, 6 조합이 나올 확률

from math import comb

sample_space_size = comb(45,6)
print (f"표본공간 (총{sample_space_size})개")
prob = 1 / sample_space_size
print(f"확률 : {prob:.10f}")
# Out:
# 표본공간 (총8145060)개
# 확률 : 0.0000001228

# %% [markdown]
# # 확률 밀도 함수
# - 확률변수가 연속형일 때, 특정 값에 정확히 도달할 확률은 0이다.
#   + 대신, 어떤 특정 구간 안에 있을 확률을 구한다.
#   + 확률 밀도 함수는 이 구간의 확률을 적분으로 표현한 함수
#   + ex) 김문수가 득표 할 확률은 14.3%다 ==> 이렇게 맞출수 없음 ==> 대신 어떤 특정 구간 안에 있을 확률을 구함
# - 예시
#   + 키가 정확히 170cm일 확률은 0
#   + P(169.5 < 키 < 170.5)는 구할 수 있다.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# 평균 0, 표준편차 1인 정규분포
x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, loc=0, scale=1)

# 시각화
plt.plot(x, pdf, label='PDF (μ=0, σ=1)')
plt.title('확률밀도함수 (정규분포)')
plt.xlabel('x')
plt.ylabel('밀도')
plt.grid(True)
plt.legend()
plt.show()

# %%
# -1 < x < 1 이 있을 확률
#p(-1 < x < 1)
prob = norm.cdf(1) - norm.cdf(-1)
print(prob)
# Out:
# 0.6826894921370859

# %% [markdown]
# ## 문제 확률 계산
# - 평균 키 = 170
# - 표준편차 = 5
# - 문제 : 169.5 < x < 170.5 일 확률은 어떻게 될까요?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# 평균, 표준편차
mu = 170
sigma = 5

prob = norm.cdf(170.5, loc=mu, scale=sigma) - norm.cdf(169.5, loc=mu, scale=sigma)
print(f'P(169.5 < 키(cm) < 170.5): {prob:.6f}')
# Out:
# P(169.5 < 키(cm) < 170.5): 0.079656

# %%
# x축 범위와 PDF 계산
x = np.linspace(150, 190, 100)
pdf = norm.pdf(x, loc=mu, scale=sigma)

# 객체 지향 방식
fig, ax = plt.subplots(figsize=(8, 5))

# PDF 곡선
ax.plot(x, pdf, label='정규분포 PDF')

# 확률이 해당되는 구간 채우기
ax.fill_between(x, pdf, where=(169.5 < x) & (x < 170.5), color='orange', alpha=0.5,
                label='P(169.5 < x < 170.5)')

# 제목 및 레이블 설정
ax.set_title('키의 확률밀도함수 (N(170, 5²))')
ax.set_xlabel('키 (cm)')
ax.set_ylabel('밀도')
ax.legend()
ax.grid(True)

# 그래프 출력
plt.show()

# %%
# 해답, p142
import scipy.special
A = [0, 1, 2]
trials = 4
event_prob = 1/2
np.sum(scipy.special.comb(trials, A) * event_prob ** trials)
# Out:
# np.float64(0.6875)

# %%
x = sympy.Symbol('x')
PA = sympy.integrate(sympy.exp(-x), (x, 0, sympy.oo))
PA
# Out:
# 1

# %%
# 특정 이벤트의 확률 구하기
x = sympy.Symbol('x')
PA = sympy.integrate(sympy.exp(-x), (x, 0, 1))
PA
# Out:
# 1 - exp(-1)

# %% [markdown]
# # 균등 분포
# - 정의 : 모든 값이 동일한 확률로 나타나는 확률분포
# - 종류 : 이산 균등분포, 연속 균등분포
#   + 이산 균등분포의 예) 주사위 : 정수 1~6이 각각 똑같은 확률로 나옴
#   + 연속 균등분포 : 실수 구간 [a,b]에서 무작위 추출
#
# - 문제 : 내가 평균적으로 버스를 몇분 기다려야 합니까?
#   + 버스를 기다리는 시간 0~10분 사이의 균등분포를 따른다고 가정(배차시간 0~10분 사이에는 출발)
#   + 승객은 평균적으로 몇분 기다리는가?
# - 수식 흐름도 : 기대값 E[X] === 적분 ===> 분산값 VAR(X) = (b-a)^2 / 12
#   + 모든 값을 균일하게 포함, 전체 길이 구간(b-a)에 따라 확산 정도(분산)가 결정된다.
#   + 분산은 단순히 제곱 폭 만큼 퍼지지 않는다. (12로 나누기 때문)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, uniform

# 균등분포 정의, 0~10
a=0
b=10
x=np.linspace(a-1, b+1, 1000) # 1000개의 데이터 의미
pdf = uniform.pdf(x, loc=a, scale=(b-a))

# 기대값
expected = (a+b) / 2
variance = ((b-a) ** 2) / 12

print(f"기댓값 E[X]: {expected}")
print(f"분산 Var[X]: {variance:.4f}")

# 시각화
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, pdf, label='PDF: Uniform(0, 10)', color='blue')
ax.axvline(expected, color='red', linestyle='--', label=f'E[X] = {expected}')
ax.set_title('연속 균등분포 PDF (Uniform(0, 10))')
ax.set_xlabel('x')
ax.set_ylabel('밀도')
ax.set_ylim(0, 0.15)
ax.legend()
ax.grid(True)
plt.show()
# Out:
# 기댓값 E[X]: 5.0
# 분산 Var[X]: 8.3333

# %%
# 예제: 균등 분포의 분포함수
# 1) 구간 [0, 1]에서 정의된 균등 분포의 분포 함수를
# 정의하세요
# 2) 분포 함수를 x값에 따른 그래프를 그리세요

# %%
# 해답 
#1)
a, b, x = sympy.symbols('a, b, x')
x = sympy.Symbol('x')
F = sympy.Lambda((x, a, b), x/(b-a))
F(x, 0, 1)
# Out:
# x

# %%
# 2)
x = np.linspace(0,1, 100)
cdf_x = x

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(x, cdf_x)
ax.set_xlabel("균등확률변수값")
ax.set_ylabel("F(x)=Pr(X<=x)")

plt.tight_layout()

# %%
# 균등 분포의 기대값 구하기
x = sympy.Symbol('x')
mu = sympy.integrate(x*1/2, (x, -1, 1))
mu
# Out:
# 0

# %%
# 분산 구하기
EX2 = sympy.integrate(x**2*1/2, (x, -1, 1))
EX2
# Out:
# 1/3

# %%
sigma2 = EX2 - mu**2
sigma2
# Out:
# 1/3

# %%
sigma = sympy.sqrt(sigma2)
sigma
# Out:
# sqrt(3)/3

# %%
# 기대값
import sympy

a, b, x = sympy.symbols('a, b, x')
mu = sympy.integrate(x/(b-a), (x, a, b))
mu.simplify().together()
# Out:
# (a + b)/2

# %%
# 제곱 기대값
EX2 = sympy.integrate(x**2/(b-a), (x, a, b))
EX2.simplify().factor()
# Out:
# (a**2 + a*b + b**2)/3

# %%
# 분산 계산
sigma2 = EX2 - mu**2
sigma2.simplify().factor()
# Out:
# (a - b)**2/12

# %%
# 적률 함수를 이용한 평균, 분산 구하기
mu, sigma, t = sympy.symbols('mu, sigma, t')
m_gen= sympy.exp(mu*t + (sigma**2 * t**2)/2)
# 1차 적률 구하기
m_gen.diff(t)
# Out:
# (mu + sigma**2*t)*exp(mu*t + sigma**2*t**2/2)

# %%
# 1차 적률: t=0
m_gen_func = sympy.Lambda(t, m_gen.diff(t))
EX = m_gen_func(0)
EX
# Out:
# mu

# %%
# 2차 적률 구하기
m_gen.diff(t, 2)
# Out:
# (sigma**2 + (mu + sigma**2*t)**2)*exp(t*(mu + sigma**2*t/2))

# %%
m_gen_func = sympy.Lambda(t, m_gen.diff(t, 2))
# 2차 적률: t=0
EX2 = m_gen_func(0)
EX2
# Out:
# mu**2 + sigma**2

# %%
# 분산
EX2 - EX**2
# Out:
# sigma**2
