# %% [markdown]
# # Section 05. 기타 데이터형

# %% [markdown]
# ## 1. Boolean

# %%
1 < 2
# Out:
# True

# %%
one_less_two=1 < 2 
one_less_two
# Out:
# True

# %%
True==False
# Out:
# False

# %%
1==2
# Out:
# False

# %%
1==1
# Out:
# True

# %%
true_equals_false=True==False
true_equals_false
# Out:
# False

# %% [markdown]
# ##2. No Value

# %%
all([True, 1, {3}])
# Out:
# True

# %%
all([True, 1, {}])
# Out:
# False

# %%
any([True, 1, {}])
# Out:
# True

# %%
any([False, 0, {}])
# Out:
# False
